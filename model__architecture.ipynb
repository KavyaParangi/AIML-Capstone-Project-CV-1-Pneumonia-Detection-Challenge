# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaParangi/AIML-Capstone-Project-CV-1-Pneumonia-Detection-Challenge/blob/master/model__architecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from keras import models  
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation  
from keras_visualizer import visualizer 
from keras import layers 
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "Share"
# Out:
# ls: cannot access 'Share': No such file or directory

# %%
model= tf.keras.models.load_model('/content/drive/My Drive/Capstone_CV_Project/Trained_model/classifier/resnet50v2classifier.h5')
# model.summary()
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 989 kB 5.2 MB/s
# ...

# %%
import visualkeras
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=1123x1195 at 0x7FE0BF05ACD0>

# %%
from PIL import ImageFont
visualkeras.layered_view(model, legend=True, scale_xy=1, scale_z=1, max_z=100, spacing=20, draw_funnel=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=561x371 at 0x7FE0BF461550>

# %%
model.layers

# %%
for layer in model.layers:
  print(layer.name.title)
# Out:
# <built-in method title of str object at 0x7fe0c3c5cc70>
# <built-in method title of str object at 0x7fe0c3c60940>
# <built-in method title of str object at 0x7fe0c3c55760>
# <built-in method title of str object at 0x7fe0c3c5c7f0>
# <built-in method title of str object at 0x7fe0c33d8970>
# <built-in method title of str object at 0x7fe0c33d8b70>
# <built-in method title of str object at 0x7fe0c33d8cf0>
